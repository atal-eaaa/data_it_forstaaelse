# %% [markdown]
# # Lektion 3
#
# Denne notebook indeholder øvelserne fra lektion 3 med plads til at skrive løsninger i kodeceller.

# %% [markdown]
# ## 1. Pandas getting startet (fortsat)
#
# Du skal fortsætte med at arbejde på data i pythonfilen fra dagens præsentation.

# %% [markdown]
# ### Opgave 1.1: Filtrering (Find Specifikke Køb)
#
# Dette svarer til at bruge Excels Filter-funktion.
# Filter 1: Vis kun de rækker (køb), hvor `Pris_DKK` er over `20.00`.
# Filter 2: Vis kun de rækker (køb), der er foretaget ved `Frokost` tidspunktet.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 1.2: Aggregering (Oversigt/Beregninger)
#
# Dette svarer til at bruge SUM/MIDDEL funktioner eller Pivot Tabeller i Excel.
# Gennemsnit: Hvad er den gennemsnitlige pris for et køb i kantinen? Hint: brug `.mean()` på kolonnen `Pris_DKK`.
# Gruppering og tælling (Pivot Tabel): Hvor mange gange er hver enkelt vare (`Pizza Slice`, `Vand`, etc.) blevet solgt? Hint: brug `.value_counts()` på kolonnen `VareNavn`.

# %%
# Skriv din løsning her

# %% [markdown]
# ## 2. Pandas mere opvarmning
#
# Lav små pandas-programmer og forklar, hvad de gør.

# %% [markdown]
# ### Opgave 2.1: Lav et lille pandas program
#
# Lav dette lille pandas program eksempel.
# Navngiv det `pd_simple.py` og prøvekør det.
# Hvilke datatyper og datastruktur er der anvendt?
# Forklar hvad programmet gør.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 2.2: Lav en dataserie
#
# En metode i pandas er at lave en dataserie.
# Lav dette lille program, navngiv det `pd_serie.py`.
# Hvilke datatyper og datastruktur er der anvendt?
# Forklar hvad programmet gør.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 2.3: Adressere data i datasættet
#
# Når vi har nogle data, vil vi gerne kunne adressere dem – altså hente data ud fra datasættet og arbejde videre med dem.
# Tilføj denne lille stump kode nederst i dit `pd_serie.py` program.
# Forklar hvad de enkelte kodelinjer gør.

# %%
# Skriv din løsning her

# %% [markdown]
# ## 3. Funktioner og menuvalg
#
# Fra dagens lektion/præsentation har du et skelet til at opbygge en menu.

# %% [markdown]
# ### Opgave 3.1: Momsberegning
#
# Opret en funktion, der beregner prisen inklusiv moms, og test at den fungerer korrekt.
# Skriv funktionen.
# Opret en funktion ved navn `beregn_totalpris_med_moms`.
# Funktionen skal acceptere én parameter: `pris_uden_moms`.
# Funktionen skal returnere prisen med 25% moms lagt til.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 3.2: Indkøbskurv og Summering
#
# I denne opgave skal du håndtere en liste af værdier og bruge den indbyggede Python-funktion `sum()` til at beregne et totalbeløb.
# Skriv funktionen.
# Opret en funktion ved navn `summer_indkobsliste`.
# Funktionen skal acceptere én parameter: `priser_liste`, som skal være en liste af tal (priser).
# Funktionen skal returnere det samlede beløb for alle priserne i listen.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 3.3: Rabatlogik og Betingelser
#
# I opgaven skal du bruge betingede udtryk (`if/else`) inde i en funktion, til at styre logikken og returnere forskellige resultater.
# Skriv funktionen.
# Opret en funktion ved navn `beregn_pris_med_kundediscount` – alle priser er inkl moms.
# Funktionen skal acceptere én parameter: `total_belob` (kundens beløb før rabat).
# Funktionen skal tjekke: Hvis beløbet er større end 100 DKK, skal der gives 10% rabat (=0.1). Ellers skal beløbet returneres uden ændring.
# Returner den endelige pris, som kunden skal betale.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 3.4: Lav menustyring til dine funktioner
#
# Du skal nu tilføje de 3 funktioner du lige har lavet til menustrukturen – så brugeren kan vælge funktionalitet via en CLI menu.
# Din menu skal nu ændres, så din brugermenu ser sådan her ud:
# [1] – Momsberegning
# [2] – Summering af indkøbskurv
# [3] – Beregning af rabat
# [0] – Exit
# Tilpas logik fra menu kode, så menuen kalder de funktioner du lige har lavet.

# %%
# Skriv din løsning her

# %% [markdown]
# ## 4. Pandas Dataanalyse (Menuvalg 4 og 5)
#
# Nu skal du skrive to nye funktioner, der bruger Pandas til at analysere data.

# %% [markdown]
# ### Opgave 4.1: Gennemsnitlig Pris
#
# Opret en ny funktion kaldet `vis_gennemsnit_pris()`.
# Funktionen skal:
# Beregne gennemsnitsprisen for alle køb i `df_kantine` (ved brug af `.mean()`).
# Prințe den beregnede gennemsnitspris.
# Kunne vælges af brugeren med menupunkt `[4]` fra din CLI menu.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 4.2: Vareopgørelse (Frequency Analysis)
#
# Opret en ny funktion kaldet `vis_salg_optælling()`.
# Funktionen skal bruge Pandas `.value_counts()` til at tælle, hvor mange gange hver enkelt vare (`VareNavn`) er blevet solgt.
# Prințe resultatet af optællingen.
# Kunne vælges af brugeren med menupunkt `[5]` fra din CLI menu.

# %%
# Skriv din løsning her

# %% [markdown]
# ## 5. Avanceret analyse (Menuvalg 6)
#
# Udvid programmet med en filtreringsfunktion, der viser, hvor stærk Pandas er til at filtrere data.

# %% [markdown]
# ### Opgave 5.1: Filtrering efter Tidspunkt
#
# Opret en ny funktion kaldet `vis_frokost_salg()`.
# Funktionen skal filtrere `df_kantine` til kun at inkludere rækker, hvor `Købstidspunkt` er lig med `Frokost`.
# Funktionen skal printe den filtrerede DataFrame.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 5.2: Opdater Menuen
#
# Tilføj `[6] Vis Frokost Salg` til `menu_print()`.
# Opdater `menu_valg()` til at kalde `vis_frokost_salg()` ved brugervalg "6".

# %%
# Skriv din løsning her
