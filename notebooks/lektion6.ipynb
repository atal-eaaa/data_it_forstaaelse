# %% [markdown]
# # Lektion 6
#
# Denne notebook indeholder øvelserne fra lektion 6 med plads til at skrive løsninger i kodeceller.

# %% [markdown]
# ## 1. Temperaturomregner
#
# Repetition af data types, if/else og functions. Lav flowchart og dokumenter kode med kommentarer.

# %% [markdown]
# ### Opgave 1.1: Omregning Celsius til Fahrenheit
#
# Lav en funktion `celsius_to_fahrenheit(celsius)` der omregner fra Celsius til Fahrenheit.
# Formlen er: `F = C × 9/5 + 32`.
# Test med `celsius = 0`, `100` og `-40`.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 1.2: Omregning Fahrenheit til Celsius
#
# Udvid med en funktion `fahrenheit_to_celsius(fahrenheit)` der omregner den anden vej.
# Lav en funktion `temperatur_omregner()` der spørger brugeren om de vil omregne `C til F` eller `F til C`.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 1.3: Fejlhåndtering for input
#
# Tilføj fejlhåndtering: Hvis brugeren indtaster noget der ikke er et tal, skal programmet give en fejlbesked og spørge igen.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 1.4: Omregning af flere temperaturer
#
# Lav en liste med temperaturer og brug en løkke til at omregne dem alle på én gang.

# %%
# Skriv din løsning her

# %% [markdown]
# ## 2. Ordtæller
#
# Repetition af strings, loops, functions og introduktion til dicts.

# %% [markdown]
# ### Opgave 2.1: Tæl ord i en tekst
#
# Lav en funktion der tager en tekst-streng og returnerer antal ord i strengen.
# Hint: Brug `.split()` metoden.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 2.2: Tæl forekomster af ord
#
# Udvid funktionen til også at tælle hvor mange gange hvert ord forekommer.
# Returner et dictionary med ord som nøgler og antal som værdier.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 2.3: Case-insensitive og tegnrensning
#
# Gør funktionen case-insensitive (så `Python` og `python` tælles som det samme ord).
# Fjern også punktummer og kommaer fra ordene.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 2.4: Find de 3 mest almindelige ord
#
# Find og print de 3 mest almindelige ord i teksten.

# %%
# Skriv din løsning her

# %% [markdown]
# ## 3. Liste-operationer
#
# Repetition af lists, loops, functions og if/else.

# %% [markdown]
# ### Opgave 3.1: Find største tal
#
# Lav en funktion `find_max(liste)` der finder det største tal i en liste uden at bruge `max()`.
# Brug en løkke til at gennemgå listen.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 3.2: Find gennemsnit
#
# Lav en funktion `find_gennemsnit(liste)` der beregner gennemsnittet af tallene i listen.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 3.3: Filtrer lige tal
#
# Lav en funktion `filtrer_lige_tal(liste)` der returnerer en ny liste med kun de lige tal.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 3.4: Kombiner funktionerne
#
# Kombiner funktionerne: Tag en liste, filtrer de lige tal, og find gennemsnittet af dem.

# %%
# Skriv din løsning her

# %% [markdown]
# ## 4. Bruger-database
#
# Repetition af lists, loops, functions og mere introduktion af dicts.

# %% [markdown]
# ### Opgave 4.1: Opret en bruger-database
#
# Lav et dictionary med 3 brugere. Hver bruger skal have: navn, alder og by.
# Eksempel: `db_dict = {"bruger1": {"navn": "Anna", "alder": 25, "by": "Aarhus"}}`.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 4.2: Find bruger
#
# Lav en funktion `find_bruger(database, navn)` der søger efter en bruger baseret på navn.
# Returner brugerens information hvis fundet, ellers returner `Bruger ikke fundet`.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 4.3: Filtrer efter by
#
# Lav en funktion `filtrer_efter_by(database, by)` der returnerer alle brugere fra en bestemt by.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 4.4: Tilføj ny bruger
#
# Lav en funktion der kan tilføje en ny bruger til databasen, men kun hvis navnet ikke allerede eksisterer.

# %%
# Skriv din løsning her

# %% [markdown]
# ## 5. Tabel-generator
#
# Repetition af loops (range), functions og string formatting.

# %% [markdown]
# ### Opgave 5.1: Gangetabel for et tal
#
# Lav en funktion der printer gangetabellen for et givet tal (f.eks. 5-tabellen).
# Brug en `for` løkke med `range(1, 11)`.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 5.2: Flere rækker
#
# Lav funktionen så den tager to parametre: tallet og hvor mange rækker der skal printes.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 5.3: Pæn formatering
#
# Formater outputtet pænt så alle tal står i kolonner.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 5.4: Hel gangetabel
#
# Lav en funktion der printer en hel gangetabel (1-10) i tabel-format.

# %%
# Skriv din løsning her

# %% [markdown]
# ## 6. Filhåndering - Tekstfil
#
# Repetition af file handling (txt), functions og strings.

# %% [markdown]
# ### Opgave 6.1: Skriv navne til tekstfil
#
# Lav en funktion der skriver en liste af navne til en tekstfil (et navn per linje).
# Test med listen: `["Anna", "Peter", "Maria", "Jan"]`.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 6.2: Læs navne fra tekstfil
#
# Lav en funktion der læser tekstfilen og returnerer navnene som en liste.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 6.3: Tilføj navn til fil
#
# Lav en funktion der tilføjer et nyt navn til filen uden at overskrive de eksisterende navne.
# Hint: Brug mode `a` for append.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 6.4: Tæl linjer i fil
#
# Lav en funktion der tæller hvor mange linjer der er i filen og returnerer antallet.

# %%
# Skriv din løsning her

# %% [markdown]
# ## 7. Pandas Dataframe
#
# Repetition af pandas, dicts, functions og exceptions.

# %% [markdown]
# ### Opgave 7.1: Opret DataFrame
#
# Opret en DataFrame med følgende data:
# `data = {'navn': ['Anna', 'Peter', 'Maria', 'Jan'], 'alder': [25, 30, 22, 35], 'by': ['Aarhus', 'København', 'Aarhus', 'Odense']}`

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 7.2: Print DataFrame
#
# Print DataFrame'en.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 7.3: Gennemsnitsalder
#
# Find og print gennemsnitsalderen af alle personer.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 7.4: Personer fra Aarhus
#
# Find og print alle personer fra Aarhus.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 7.5: Tilføj kolonne og række
#
# Tilføj en ny kolonne `land` med værdien `Danmark` for alle rækker.
# Tilføj en ny række med en ny person.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 7.6: Gem og indlæs CSV
#
# Gem DataFrame'en til en CSV-fil og indlæs filen igen (med try-except handling) for at teste at det virker.

# %%
# Skriv din løsning her

# %% [markdown]
# ## 8. Kontaktbog del 1
#
# Repetition af funktioner og CLI-menu.

# %% [markdown]
# ### Opgave 8.1: Start med menu-kode
#
# Start med menu-koden fra lektion pyt3 og byg en kontaktbog.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 8.2: Tilføj kontakt
#
# Implementer funktionen til at tilføje en kontakt.
# Den skal spørge om navn, telefon og email.
# Gem kontakten som et dictionary i listen: `{"navn": "Anna", "telefon": "12345678", "email": "anna@mail.dk"}`.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 8.3: Vis alle kontakter
#
# Lav kode til `Vis alle kontakter` – brug en løkke til at printe alle kontakter pænt formateret.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 8.4: Søg efter kontakt
#
# Lav kode til `Søg efter kontakt` – søg efter navn og vis kontaktens information hvis fundet.

# %%
# Skriv din løsning her

# %% [markdown]
# ## 9. Kontaktbog – fortsat del 2
#
# Repetition af file handling og pandas.

# %% [markdown]
# ### Opgave 9.1: Gem kontakter til fil
#
# Tilføj menupunkt `[4] Gem kontakter til fil`.
# Implementer en funktion der gemmer alle kontakter til en tekstfil – en kontakt per linje i formatet: `navn,telefon,email`.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 9.2: Indlæs kontakter fra fil
#
# Tilføj menupunkt `[5] Indlæs kontakter fra fil`.
# Implementer en funktion der læser tekstfilen og tilføjer kontakterne til listen.
# Hint: Brug `.split(",")` til at dele hver linje op.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 9.3: Brug CSV-format
#
# Lav koden om, så du bruger CSV format i stedet.
# Brug Pythons indbyggede `csv` modul eller pandas.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 9.4: Automatisk gem/indlæs ved start og slut
#
# Automatisk indlæs kontakter fra filen når programmet starter (hvis filen eksisterer).
# Gem automatisk når programmet afsluttes.

# %%
# Skriv din løsning her

# %% [markdown]
# ## 10. Kontaktbog – fortsat del 3
#
# Repetition af pandas og csv.

# %% [markdown]
# ### Opgave 10.1: Konverter til DataFrame
#
# Konverter kontaktbogen til at bruge Pandas DataFrame i stedet for en liste.
# Erstat den globale kontakter liste med en global DataFrame.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 10.2: Tilføj kontakt med DataFrame
#
# Modificer `Tilføj kontakt` funktionen til at tilføje en ny række til DataFrame'en.
# Hint: Brug `pd.concat()` eller `.loc[]`.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 10.3: Vis alle kontakter med pandas
#
# Lav `Vis alle kontakter` om, så den bruger pandas til at vise dataen pænt.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 10.4: Søg efter kontakt med pandas
#
# Lav `Søg efter kontakt` om til at bruge pandas filtering.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 10.5: Nye menupunkter
#
# Tilføj nye menupunkter:
# - Sorter kontakter alfabetisk
# - Vis statistik (antal kontakter, antal unikke email-domæner)
# - Slet en kontakt baseret på navn
# Hint: Brug `.to_csv()` og `pd.read_csv()` til at gemme/indlæse DataFrame'en.

# %%
# Skriv din løsning her
