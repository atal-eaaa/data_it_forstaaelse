# %% [markdown]
# # Lektion 4
#
# Denne notebook indeholder øvelserne fra lektion 4 med plads til at skrive løsninger i kodeceller.

# %% [markdown]
# ## 1. Afholdte events
#
# Analysér eventsalg, økonomi og deltageradfærd ved at berige datasættet med nye, beregnede kolonner.

# %% [markdown]
# ### Opgave 1.1: Forbered datasæt
#
# Datasættet er indlæses i en 2D-liste kaldet `events_data`.
# Kolonnenavnene laves i en separat liste kaldet `header`.
# Bemærk: Alle numeriske kolonner (priser, temperatur, km, scores, etc.) er allerede konverteret til `int` eller `float`.
# Koden findes som `data_sim1000.py` på Canvas.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 1.2: Datatransformation (Tid/Dato)
#
# Erstat kolonnen `event_date` (index 1) med to nye kolonner:
# - `Event_År` (int)
# - `Ugedag` (str, f.eks. `Man`, `Tirs`, `Fre`)
# Gem det transformerede datasæt i `transformed_data`.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 1.3: Økonomisk berigelse
#
# Tilføj en ny kolonne: `Total_Spend_DKK`.
# Beregn den samlede udgift pr. deltager ved at summere `final_ticket_price_dkk`, `online_fee_dkk`, `transport_cost_dkk`, `merch_spend_dkk` og `food_spend_dkk`.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 1.4: Betinget klassificering
#
# Tilføj en ny kolonne: `Ticket_Category`.
# Klassificer billetten som `Lav` (hvis `base_ticket_price_dkk` er under `250` DKK) eller `Høj` (hvis den er `250` DKK eller derover).

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 1.5: Avanceret metrisk
#
# Tilføj en ny kolonne: `Tilfredshed_Pr_DKK`.
# Beregn forholdet mellem deltagerens `satisfaction_score` og deres samlede udgift (`Total_Spend_DKK` fra trin 2).
# Vigtigt: Undgå division med nul ved at sætte værdien til `0`, hvis den samlede udgift er `0`.

# %%
# Skriv din løsning her
