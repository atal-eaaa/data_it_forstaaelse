# %% [markdown]
# # Lektion 5
#
# Denne notebook indeholder øvelserne fra lektion 5 med plads til at skrive løsninger i kodeceller.

# %% [markdown]
# ## 1. Kom-i-gang: Fejlhåndtering: try-except
#
# Skriv funktioner med try/except for at håndtere fejl på en robust måde.

# %% [markdown]
# ### Opgave 1.1: Dividering med fejlhåndtering
#
# Skriv en funktion, der tager to tal og dividerer det første med det andet.
# Brug try-except til at fange en `ZeroDivisionError` og udskriv beskeden: `Fejl: Du kan ikke dividere med nul!`.
# Test: Kald funktionen først med tallene `10` og `0`, derefter med `8` og `4`.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 1.2: Konvertering af input til heltal
#
# Skriv en funktion, der tager et input og forsøger at konvertere det til et heltal (`int`).
# Brug try-except til at fange en `ValueError` og udskrive: `Fejl: Input skal være et gyldigt tal!`.
# Hvis konverteringen lykkes, udskrives tallet.
# Kald funktionen to gange: én gang med et gyldigt tal i anførselstegn (`"5"`) og én gang med en tekststreng (`"hej"`).

# %%
# Skriv din løsning her

# %% [markdown]
# ## 2. Fejlhåndtering af fil-indlæsning og forberedelse af data
#
# Indlæs data fra fil og håndter fejl sikkert.

# %% [markdown]
# ### Opgave 2.1: Indlæs DataFrame fra fil
#
# Indlæs en Pandas DataFrame fra filen `ftp_data.csv`.
# Udskriv de første 5 rækker af dataframen.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 2.2: Fejlhåndtering ved filindlæsning
#
# Lav kode så indlæsningen fra din kode nu er inde i en try-except blok.
# Brug `except FileNotFoundError` til at udskrive: `Fejl: Filen blev ikke fundet. Tjek filnavnet og placeringen!`.
# Kald din kode med fejlhåndtering, hvor du forsøger at indlæse filen `missing.csv` (som ikke findes).
# Check at der udskrives en fejlbesked – og koden ikke crasher.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 2.3: Beregning af gennemsnit og generel fejlhåndtering
#
# `ftp_data.csv` har kolonnerne `Score_daglig` og `Score_konkurrence`.
# Beregn gennemsnittet af kolonnen `Værdi`.
# Indsæt et generelt `except` til sidst i blokken fra 2.2, der fanger fejl (fx hvis der ikke er nogen værdi, hvis datatype er forkert o.s.v.) og udskriver: `Der skete en fejl under datahåndtering.`
# Hvordan kan du gøre din fejlmeddelelse mere specifik?

# %%
# Skriv din løsning her

# %% [markdown]
# ## 3. Matplotlib – kurver- og scatterplot
#
# Opret simple visualiseringer med matplotlib og pandas.

# %% [markdown]
# ### Opgave 3.1: Kurveplot
#
# Importer `matplotlib.pyplot as plt`.
# Indlæs CSV-datasæt i en pandas DataFrame – hvis du ikke allerede har gjort det tidligere i opgaven.
# Opret et simpelt kurveplot ved hjælp af `x_værdier` og `y_værdier`.
# Sæt titel, og vis plottet.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 3.2: Scatterplot
#
# Konverter det nuværende kurveplot til et scatterplot ved hjælp af den relevante funktion.
# Sæt aksetitler (`plt.xlabel` og `plt.ylabel`) som `Målinger` og `Resultater`.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 3.3: Kombineret plot
#
# Kombiner kurveplottet og scatterplottet i samme figur.
# Vis både punkterne (scatter) og linjen (plot) og tilføj en forklaring (`plt.legend`) til plottet, der differentierer de to.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 3.4: Gem plot som fil
#
# Gem plottet som en fil med navnet `mit_første_plot.png` uden at vise plottet på skærmen.

# %%
# Skriv din løsning her

# %% [markdown]
# ## 4. Visualisering og dataforberedelse (Filtrering og Skalering)
#
# Filtrer data, lav søjlediagrammer og skaler kolonner.

# %% [markdown]
# ### Opgave 4.1: Indlæs og vis data
#
# Indlæs en Pandas DataFrame fra filen `ftp_data.csv`.
# Udskriv de første 5 rækker af dataframen (gentagelse af opgave 2).

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 4.2: Filtrering af byer
#
# Opret en ny DataFrame kaldet `kbh_aarhus_df`, der kun indeholder de rækker, hvor værdien i kolonnen `By` er lig med `København` eller `Aarhus`.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 4.3: Søjlediagram over byer
#
# Opret et søjlediagram over antallet af personer i de unikke byer.
# Brug en Pandas-funktion til at tælle forekomsterne af hver by (`value_counts()`) og plot resultatet.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 4.4: Skalering af alder
#
# Skaler kolonnen `Alder` i den oprindelige `ftp_data` dataframe til at ligge mellem `0` og `1`.
# Normalisering kan beregnes som: `(Alder - min(Alder)) / (max(Alder) - min(Alder))`.
# Opret en ny kolonne kaldet `Skaleret_Alder` med de skalerede værdier.

# %%
# Skriv din løsning her

# %% [markdown]
# ### Opgave 4.5: Scatterplot med skaleret alder
#
# Opret et nyt scatterplot, der viser `Skaleret_Alder` (y-akse) mod et simpelt indeks (række-nummeret/rækkenumre fra `0` til `N`, x-aksen).
# Tilføj et gitter (`plt.grid(True)`).

# %%
# Skriv din løsning her
